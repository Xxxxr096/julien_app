# %%
import pandas as pd

# %%
p = pd.read_csv("fusion_complete_avec_colonnes.csv")
f = pd.read_csv("clean_spv_data.csv")
p.isnull().sum()
# Out:
# Cie                                             1
# UT                                            230
# Matricule                                       0
# Age                                             1
# Sexe                                            1
# Aptitude générale                            1689
# Dernière visite                              1689
# date_visite                                     1
# Prochaine visite                             1696
# Date prochaine visite                        1696
# Date dernière biométrie                      1695
# IMC                                          1695
# Taille                                       1695
# Poids                                        1695
# Périmètre abdominal                          1793
# Tension artérielle systol                    1819
# Tension artérielle Diastol                   1819
# Incendie et port de l'ARI Toutes missions       4
# source                                          0
# ...

# %%
merged_data = f.merge(
    p[['Matricule', 'Sexe']],
    on='Matricule',
    how='left'
)

merged_data.head()
# Out:
#           Cie_x            UT_x  Matricule  Age_x Date derniers ICP Luc léger  \
# 0   Cie EMS Sud   UT Fegersheim      34678   63.0           9/30/24       0,0
# 1  Cie Haguenau     UT Haguenau      36429   40.0           9/27/24       0,0
# 2  Cie Molsheim       UT Urmatt      23469   60.0          11/28/23       0,0
# 3   Cie Saverne  UT Diemeringen      26329   61.0          10/16/24       0,0
# 4   Cie Saverne  UT Diemeringen      32848   60.0           9/15/24       0,0
#
#    Niveau Luc léger  Pompes  Niveau pompes  Tractions  ...  \
# 0               1.0    15.0            3.0        2.0  ...
# 1               1.0    20.0            3.0        7.0  ...
# 2               1.0    20.0            3.0        1.0  ...
# 3               1.0     0.0            1.0        0.0  ...
# 4               1.0     7.0            2.0        0.0  ...
#
#    Date dernière visite Date dernière biométrie    IMC  Taille  Poids  \
# ...

# %%
merged_data.isnull().sum()
# Out:
# Cie_x                                          0
# UT_x                                           0
# Matricule                                      0
# Age_x                                          0
# Date derniers ICP                              0
# Luc léger                                      0
# Niveau Luc léger                               0
# Pompes                                         0
# Niveau pompes                                  0
# Tractions                                      0
# Niveau tractions                               0
# Aptitude générale                              0
# Date dernière visite                           0
# Date dernière biométrie                        0
# IMC                                            0
# Taille                                         0
# Poids                                          0
# Périmètre abdominal                            0
# Tension artérielle systol                      0
# ...

# %%
merged_data.to_csv("merged_data_spv.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 merged_data.to_csv("merged_data_spv.csv",index=False)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
merged_data["Luc léger"] = merged_data["Luc léger"].str.replace(",", ".", regex=False).astype(float)

# %%
merged_data.loc[merged_data["Luc léger"] == 0, "Niveau Luc léger"] = 0

# %%
merged_data.to_csv("merged_data_spv.csv",index=False)

# %%
pdf = pd.read_csv("merged_data_spv.csv")

# %%
pdf.columns
# Out:
# Index(['Cie_x', 'UT_x', 'Matricule', 'Age_x', 'Date derniers ICP', 'Luc léger',
#        'Niveau Luc léger', 'Pompes', 'Niveau pompes', 'Tractions',
#        'Niveau tractions', 'Aptitude générale', 'Date dernière visite',
#        'Date dernière biométrie', 'IMC', 'Taille', 'Poids',
#        'Périmètre abdominal', 'Tension artérielle systol',
#        'Tension artérielle Diastol',
#        'Incendie et port de l'ARI Toutes missions_y', 'Sexe'],
#       dtype='object')

# %%
pdf["Sexe"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pdf["Sexe"]
#
# NameError: name 'pdf' is not defined

# %%
df = pd.read_csv("merged_spp.csv")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df = pd.read_csv("merged_spp.csv")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
spp_icp = pd.read_csv("spp_icp_sexe.csv",sep=";",header=None)
spp_apt = pd.read_csv("spp_apt_sexe.csv",sep=";",header=None)

# %%
spp_icp.head()
# Out:
#    0              1    2          3    4                  5          6   \
# 0 NaN            NaN  NaN        NaN  NaN                NaN        NaN
# 1 NaN            Cie   UT  Matricule  Age  Date derniers ICP  Luc léger
# 2 NaN  Cie CTA-CODIS  NaN      35702   35            5/22/24       10,0
# 3 NaN  Cie CTA-CODIS  NaN      37070   38            10/8/24       11,0
# 4 NaN  Cie CTA-CODIS  NaN      37305   37            4/17/24       10,0
#
#                  7       8              9          10                11  \
# 0               NaN     NaN            NaN        NaN               NaN
# 1  Niveau Luc léger  Pompes  Niveau pompes  Tractions  Niveau tractions
# 2                 3      20              3         20                 3
# 3                 3      40              3         20                 3
# 4                 3      20              3         15                 3
#
#                                           12
# 0                                        NaN
# ...

# %%
spp_icp.columns = spp_icp.iloc[1]

# %%
spp_icp.head()
# Out:
# 1  NaN            Cie   UT  Matricule  Age  Date derniers ICP  Luc léger  \
# 0  NaN            NaN  NaN        NaN  NaN                NaN        NaN
# 1  NaN            Cie   UT  Matricule  Age  Date derniers ICP  Luc léger
# 2  NaN  Cie CTA-CODIS  NaN      35702   35            5/22/24       10,0
# 3  NaN  Cie CTA-CODIS  NaN      37070   38            10/8/24       11,0
# 4  NaN  Cie CTA-CODIS  NaN      37305   37            4/17/24       10,0
#
# 1  Niveau Luc léger  Pompes  Niveau pompes  Tractions  Niveau tractions  \
# 0               NaN     NaN            NaN        NaN               NaN
# 1  Niveau Luc léger  Pompes  Niveau pompes  Tractions  Niveau tractions
# 2                 3      20              3         20                 3
# 3                 3      40              3         20                 3
# 4                 3      20              3         15                 3
#
# 1  Incendie et port de l'ARI Toutes missions
# 0                                        NaN
# ...

# %%
spp_icp.columns
# Out:
# Index([                                        nan,
#                                              'Cie',
#                                               'UT',
#                                        'Matricule',
#                                              'Age',
#                                'Date derniers ICP',
#                                        'Luc léger',
#                                 'Niveau Luc léger',
#                                           'Pompes',
#                                    'Niveau pompes',
#                                        'Tractions',
#                                 'Niveau tractions',
#        'Incendie et port de l'ARI Toutes missions'],
#       dtype='object', name=1)

# %%
spp_icp = spp_icp.loc[:, spp_icp.columns.notna()]

# %%
spp_icp.columns
# Out:
# Index(['Cie', 'UT', 'Matricule', 'Age', 'Date derniers ICP', 'Luc léger',
#        'Niveau Luc léger', 'Pompes', 'Niveau pompes', 'Tractions',
#        'Niveau tractions', 'Incendie et port de l'ARI Toutes missions'],
#       dtype='object', name=1)

# %%
spp_apt.head()
# Out:
#    0               1                     2          3    4   \
# 0 NaN             NaN                   NaN        NaN  NaN
# 1 NaN             Cie                    UT  Matricule  Age
# 2 NaN   Cie CTA-CODIS                   NaN      90944   41
# 3 NaN  Cie EMS Centre  UT Strasbourg Finkwi      44378   20
# 4 NaN       DIRECTION                   NaN      90520   53
#
#                   5                               6                     7   \
# 0                NaN                             NaN                   NaN
# 1  Aptitude générale                 Dernière visite  Date dernière visite
# 2               Apte  Visite de maintien en activité              12/16/24
# 3               Apte           Visite de recrutement               6/17/24
# 4               Apte  Visite de maintien en activité               6/26/24
#
#                                8                      9   \
# 0                             NaN                    NaN
# ...

# %%
spp_apt.columns = spp_apt.loc[1]

# %%
spp_apt.columns
# Out:
# Index([                                        nan,
#                                              'Cie',
#                                               'UT',
#                                        'Matricule',
#                                              'Age',
#                                'Aptitude générale',
#                                  'Dernière visite',
#                             'Date dernière visite',
#                                 'Prochaine visite',
#                            'Date prochaine visite',
#                          'Date dernière biométrie',
#                                              'IMC',
#                                           'Taille',
#                                            'Poids',
#                              'Périmètre abdominal',
#                        'Tension artérielle systol',
#                       'Tension artérielle diastol',
#        'Incendie et port de l'ARI Toutes missions'],
# ...

# %%
spp_apt = spp_apt.loc[:, spp_apt.columns.notna()]

# %%
spp_sex_data = pd.merge(spp_apt,spp_icp,how="inner")

# %%
spp_sex_data.columns
# Out:
# Index(['Cie', 'UT', 'Matricule', 'Age', 'Aptitude générale', 'Dernière visite',
#        'Date dernière visite', 'Prochaine visite', 'Date prochaine visite',
#        'Date dernière biométrie', 'IMC', 'Taille', 'Poids',
#        'Périmètre abdominal', 'Tension artérielle systol',
#        'Tension artérielle diastol',
#        'Incendie et port de l'ARI Toutes missions', 'Date derniers ICP',
#        'Luc léger', 'Niveau Luc léger', 'Pompes', 'Niveau pompes', 'Tractions',
#        'Niveau tractions'],
#       dtype='object', name=1)

# %%
merged_data_spp = df.merge(
    spp_sex_data[['Matricule', 'Sexe']],
    on='Matricule',
    how='left'
)

merged_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
#       1 merged_data_spp = df.merge(
# ----> 2     spp_sex_data[['Matricule', 'Sexe']],
#       3     on='Matricule',
#       4     how='left'
#       5 )
#       7 merged_data.head()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
